# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter
sns.set()

# %%
iris = datasets.load_iris()
X, y = iris.data, iris.target

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
X_train[:5]
# Out:
# array([[5.1, 2.5, 3. , 1.1],
#        [6.2, 2.8, 4.8, 1.8],
#        [5. , 3.5, 1.3, 0.3],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.7, 3. , 5. , 1.7]])

# %%
y_train[:5]
# Out:
# array([1, 2, 0, 2, 1])

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y, palette='Set2');

# %%
df = pd.DataFrame(np.c_[X, y])

# %%
sns.pairplot(data=df, vars=[0,1,2,3], hue=4, palette='Set2');

# %%
def euclidian_distance(x1, x2):
    return np.sqrt(np.sum(np.square(x2 - x1)))

class KNN():
    def __init__(self, k=3):
        self.k = k
        
    def fit(self, X, y):
        self.X_train = X
        self.y_train = y
    
    def predict(self, X):  
        predicted_labels = [self._predict(x) for x in X]
        return np.array(predicted_labels)
        
    def _predict(self, x):
        # calculate distances
        distances = [euclidian_distance(x, x_train) for x_train in self.X_train]
        # get k nearest neighbors
        k_indices = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        # majority vote, most common class label.
        most_common = Counter(k_nearest_labels).most_common(1)[0][0]
        return most_common

# %%
knn = KNN()
knn.fit(X_train, y_train)
y_hat = knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
f1_score(y_test, y_hat, average='macro')
# Out:
# 1.0

# %%
class KNNClassifier():
    def __init__(self, k=3):
        self.k = k
        
    def fit(self, X, y):
        self.X_train = X
        self.y_train = y
    
    def predict(self, X):
        prediction = np.array([self._predict(x) for x in X])
        return prediction
    
    def _predict(self, x):
        distances = np.sqrt(np.sum(np.square(self.X_train - x), axis=1))
        k_indices = np.argsort(distances)[:self.k]
        #print(distances)
        k_nearest_labels = self.y_train[k_indices]
        #print(k_nearest_labels)
        most_common = Counter(k_nearest_labels).most_common(1)[0][0]
        return most_common
    
    
clf = KNNClassifier()
# Out:
# (array([1, 1, 2, 0, 1, 0, 0, 0, 1, 2, 1, 0, 2, 1, 0, 1, 2, 0, 2, 1, 1, 1,
#         1, 1, 2, 0, 2, 1, 2, 0]),
#  array([1, 1, 2, 0, 1, 0, 0, 0, 1, 2, 1, 0, 2, 1, 0, 1, 2, 0, 2, 1, 1, 1,
#         1, 1, 2, 0, 2, 1, 2, 0]))

# %%
np.sum(np.square(X - np.array([-10, -10, -10, -10])), axis=1)
# Out:
# array([644.26, 625.01, 622.06, 621.06, 643.96, 675.42, 628.77, 640.85,
#        607.77, 627.88, 661.14, 637.2 , 620.01, 598.71, 675.12, 694.26,
#        666.22, 646.31, 679.91, 656.79, 657.65, 656.11, 623.16, 652.04,
#        644.25, 632.6 , 647.28, 649.58, 644.6 , 628.93, 629.25, 657.13,
#        664.11, 675.89, 629.91, 628.72, 654.23, 638.94, 608.09, 643.86,
#        641.03, 595.32, 613.33, 654.17, 668.22, 624.09, 657.05, 621.4 ,
#        658.07, 635.89, 809.29, 785.7 , 811.48, 715.23, 781.5 , 748.27,
#        793.23, 673.66, 782.82, 715.5 , 672.25, 755.7 , 721.84, 771.67,
#        722.42, 787.82, 754.86, 730.74, 753.78, 716.03, 785.33, 746.74,
#        776.2 , 764.58, 767.55, 781.88, 795.08, 809.78, 764.91, 708.5 ,
#        707.66, 702.7 , 729.58, 779.86, 748.66, 780.37, 798.84, 752.03,
#        738.86, 720.19, 731.81, 771.33, 729.84, 674.18, 733.98, 742.57,
#        742.23, 761.03, 676.47, 736.83, 854.83, 780.55, 860.63, 814.7 ,
# ...
